# %%
import pandas as pd
import numpy as np
import qiime2
# from qiime2.plugins import feature_table
from qiime2 import Artifact
from qiime2 import Metadata

# %%
n_samples = 50

# %%
features = np.random.choice(['A','C','T','G'], size=(10,10))
col_features = [''.join(feature) for feature in features]
col_features
# Out:
# ['AGCATCGGCT',
#  'CACTGTGCAC',
#  'TCGCTATGCC',
#  'GTCACTGGTT',
#  'GCATGGATGT',
#  'CAGGAATATG',
#  'CATTCACTAC',
#  'TAATGTCGGA',
#  'GTTAATCCAG',
#  'ACTGCTGCGG']

# %%
test_index = ['sample_'+ str(i) for i in range(n_samples)]

# %%
test_feature_table = pd.DataFrame(np.random.randint(0, 2, size=(n_samples,len(col_features))), columns=col_features,index=test_index)
test_feature_table
# Out:
#            AGCATCGGCT  CACTGTGCAC  TCGCTATGCC  GTCACTGGTT  GCATGGATGT  \
# sample_0            1           0           0           0           0
# sample_1            1           1           1           0           0
# sample_2            1           1           1           1           0
# sample_3            0           1           1           1           1
# sample_4            0           0           0           0           1
# sample_5            0           0           0           1           1
# sample_6            1           1           1           0           1
# sample_7            1           1           0           0           1
# sample_8            0           1           1           0           0
# sample_9            0           0           1           1           0
# sample_10           0           0           1           1           1
# sample_11           1           0           1           0           1
# ...

# %%
diseases = ["abdominal_obesity_ncep_v2", "ckd_v2", "diabetes2_v2",
                    "hypertension2_v2", "precvd_v2", "elevated_bp_selfmeds_v2","dyslipidemia_v2"]
test_metadata = pd.DataFrame(np.random.randint(0, 2, size=(n_samples,len(diseases))), columns=diseases, index = test_index)

# %%
test_metadata['ckd_v2'] = np.random.randint(1,6,size=[n_samples])
test_metadata['diabetes2_v2'] = np.random.randint(1,4, size=[n_samples])

# %%
test_metadata
# Out:
#            abdominal_obesity_ncep_v2  ckd_v2  diabetes2_v2  hypertension2_v2  \
# sample_0                           1       3             2                 1
# sample_1                           0       4             1                 1
# sample_2                           0       4             3                 1
# sample_3                           0       5             1                 1
# sample_4                           1       3             1                 0
# sample_5                           1       4             2                 0
# sample_6                           0       5             3                 1
# sample_7                           0       4             3                 0
# sample_8                           1       5             1                 1
# sample_9                           0       1             3                 1
# sample_10                          1       2             3                 0
# ...

# %%
test_metadata.to_csv('test/test_metadata.tsv', sep="\t", index_label='sampleid')

# %%
test_feature_table_artifact = Artifact.import_data("FeatureTable[Frequency]", test_feature_table.rename_axis('sampleid'))
test_feature_table_artifact.save('test/test_feature_table')
# Out:
# 'test/test_feature_table.qza'

# %%
test_feature_table.rename_axis('sampleid')
# Out:
#            AGCATCGGCT  CACTGTGCAC  TCGCTATGCC  GTCACTGGTT  GCATGGATGT  \
# sampleid
# sample_0            1           0           0           0           0
# sample_1            1           1           1           0           0
# sample_2            1           1           1           1           0
# sample_3            0           1           1           1           1
# sample_4            0           0           0           0           1
# sample_5            0           0           0           1           1
# sample_6            1           1           1           0           1
# sample_7            1           1           0           0           1
# sample_8            0           1           1           0           0
# sample_9            0           0           1           1           0
# sample_10           0           0           1           1           1
# sample_11           1           0           1           0           1
# ...
